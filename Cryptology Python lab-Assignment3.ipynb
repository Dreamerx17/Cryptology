# %%
#1
print("Welcome to Cryptology Lab");
message = "Python Programming";
print(message);
num = input("Enter a number: ")
result = num + 10
print(result)
# Out:
# Welcome to Cryptology Lab
# Python Programming
# Enter a number:  5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       1 print("Welcome to Cryptology Lab");
#       2 message = "Python Programming";
#       3 print(message);
#       4 num = input("Enter a number: ")
# ----> 5 result = num + 10
#       6 print(result)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print("Welcome to Cryptology Lab");
message = "Python Programming";
print(message);
num = int(input("Enter a number: "))
result = num + 10
print(result)
# Out:
# Welcome to Cryptology Lab
# Python Programming
# Enter a number:  5
# 15

# %%
#2
a=(input("Enter yourt message"));
b=(input("Enter your second message"));
c=(input("Enter your third message"));
print(a);
print(b);
print(c);
# Out:
# Enter yourt message Welcome to Cryptology Lab
# Enter your second message It's interesting to learn Python.
# Enter your third message Students, "Welcome to the Cryptology Lab".
# Welcome to Cryptology Lab
# It's interesting to learn Python.
# Students, "Welcome to the Cryptology Lab".

# %%
#3
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Integer division:", a // b)
print("Remainder:", a % b)
print("Exponentiation:", a ** b)
# Out:
# Enter first number:  5
# Enter second number:  2
# Addition: 7.0
# Subtraction: 3.0
# Multiplication: 10.0
# Division: 2.5
# Integer division: 2.0
# Remainder: 1.0
# Exponentiation: 25.0

# %%
#4
num = float(input("Enter a floating-point number: 2.0"))

print("Data type:", type(num))
print("Absolute value:", abs(num))
print("Rounded to two decimal places:", round(num, 2))
# Out:
# Enter a floating-point number: 2.0 25.5373783838
# Data type: <class 'float'>
# Absolute value: 25.5373783838
# Rounded to two decimal places: 25.54

# %%
#5
a = 10
b = 10.5
c = 2 + 3j
d = "Hello Python"
e = [10, 20, 30]
f = (10, 20, 30)
g = {10, 20, 30}
h = {"name": "Ayush", "age": 21}

print("Integer:", a, "Type:", type(a))
print("Float:", b, "Type:", type(b))
print("Complex:", c, "Type:", type(c))
print("String:", d, "Type:", type(d))
print("List:", e, "Type:", type(e))
print("Tuple:", f, "Type:", type(f))
print("Set:", g, "Type:", type(g))
print("Dictionary:", h, "Type:", type(h))
# Out:
# Integer: 10 Type: <class 'int'>
# Float: 10.5 Type: <class 'float'>
# Complex: (2+3j) Type: <class 'complex'>
# String: Hello Python Type: <class 'str'>
# List: [10, 20, 30] Type: <class 'list'>
# Tuple: (10, 20, 30) Type: <class 'tuple'>
# Set: {10, 20, 30} Type: <class 'set'>
# Dictionary: {'name': 'Ayush', 'age': 21} Type: <class 'dict'>

# %%
# 6 
#String
text = "Hello"

print("Original string:", text)

try:
    text[0] = "Y"
except TypeError:
    print("String cannot be changed because strings are immutable")


# List
numbers = [10, 20, 30]

print("\nOriginal list:", numbers)

numbers[0] = 100

print("Modified list:", numbers)
# Out:
# Original string: Hello
# String cannot be changed because strings are immutable
#
# Original list: [10, 20, 30]
# Modified list: [100, 20, 30]

# %%
#7
numbers = [2, 3, 5, 7, 11]


print("First three elements:", numbers[:3])


print("Last element:", numbers[-1])


numbers.append(13)


numbers.extend([17, 19])

print("Updated list:", numbers)
print("Total number of elements:", len(numbers))
# Out:
# First three elements: [2, 3, 5]
# Last element: 11
# Updated list: [2, 3, 5, 7, 11, 13, 17, 19]
# Total number of elements: 8

# %%
#8
message = "CRYPTOLOGY USING PYTHON"
print("the length of the string:",len(message))
print("the first five letter:",message[:5])
print("the last six letter:",message[-6:])
print("the character from 2 to 8:",message[2:8])
print("string in reverse order:",message[::-1])
# Out:
# the length of the string: 23
# the first five letter: CRYPT
# the last six letter: PYTHON
# the character from 2 to 8: YPTOLO
# string in reverse order: NOHTYP GNISU YGOLOTPYRC

# %%
#9
message = "CRYPTOLOGY USING PYTHON"
lowercase =message.lower()
print("Lowercase",lowercase)

uppercase= lowercase.upper()
print("Uppercase",uppercase)

print("Python exist :","Python" in message)

replaced = message.replace("Python","Programming")
print("after being replaced the answer is : ",replaced)
# Out:
# Lowercase cryptology using python
# Uppercase CRYPTOLOGY USING PYTHON
# Python exist : False
# after being replaced the answer is :  CRYPTOLOGY USING PYTHON

# %%
#10
message = "CRYPTOLOGY USING PYTHON"

result = message.replace(" ","")
print("string without the space:",result)
# Out:
# string without the space: CRYPTOLOGYUSINGPYTHON

# %%
#11
message = "CRYPTOLOGY USING PYTHON"
for char in message:
    print(char ,"->", ord(char))
# Out:
# C -> 67
# R -> 82
# Y -> 89
# P -> 80
# T -> 84
# O -> 79
# L -> 76
# O -> 79
# G -> 71
# Y -> 89
#   -> 32
# U -> 85
# S -> 83
# I -> 73
# N -> 78
# G -> 71
#   -> 32
# P -> 80
# Y -> 89
# T -> 84
# H -> 72
# O -> 79
# N -> 78

# %%
#12
values =[65,67,73,80,72,69,82]

word = ""

for value in values:
    word += chr(value)
print("characters:",word)
# Out:
# characters: ACIPHER

# %%
#13
message =input("Enter message:")
#message =message.strip()
message =message.upper()
message =message.replace(" ","")
print("Processed message:",message)
# Out:
# Enter message: hi my anme is anonymous
# Processed message: HIMYANMEISANONYMOUS

# %%
#14
message=input("Enter string:")

for i in range(0,len(message), 5):
    print(message[i:i+5])
# Out:
# Enter string: CYBERSECURITY
# CYBER
# SECUR
# ITY

# %%
#15
message=input("Enter a string: ")

for i in range(0,len(message),5):
    block=message[i:i+5]

    if len(block) < 5:
       block= block + "X" *(5 - len(block)) 

    print(block)
# Out:
# Enter a string:  CYBERSECURITY
# CYBER
# SECUR
# ITYXX

# %%
#16
text = "CRYPTOLOGYISINTERESTING"

frequency = {}

for char in text:
    if char in frequency:
        frequency[char] += 1
    else:
        frequency[char] = 1

print("character frequency:")

for char, count in frequency.items():
    print(char, "->", count)

most_frequent = max(frequency, key=frequency.get)

print("most frequently occurring character:", most_frequent)
print("frequency:", frequency[most_frequent])
# Out:
# Character Frequency:
# C -> 1
# R -> 2
# Y -> 2
# P -> 1
# T -> 3
# O -> 2
# L -> 1
# G -> 2
# I -> 3
# S -> 2
# N -> 2
# E -> 2
# Most frequently occurring character: T
# Frequency: 3

# %%
#17
text = "CRYPTOLOGYISINTERESTING"

frequency = {}

for char in text:
    if char in frequency:
        frequency[char] += 1
    else:
        frequency[char] = 1

total = len(text)

print("character frequency and percentage:")

for char, count in frequency.items():
    percentage = (count / total) * 100
    print(char, "->", count, "->", round(percentage, 2), "%")
# Out:
# character frequency and percentage:
# C -> 1 -> 4.35 %
# R -> 2 -> 8.7 %
# Y -> 2 -> 8.7 %
# P -> 1 -> 4.35 %
# T -> 3 -> 13.04 %
# O -> 2 -> 8.7 %
# L -> 1 -> 4.35 %
# G -> 2 -> 8.7 %
# I -> 3 -> 13.04 %
# S -> 2 -> 8.7 %
# N -> 2 -> 8.7 %
# E -> 2 -> 8.7 %

# %%
#18
print(29 % 26)
print(55 % 26)
print(78 % 26)
print(-3 % 26)
print(-29 % 26)

number =int(input("Enter an integer:"))
result =number %26
print(number,"mod 26 =",result)
# Out:
# 3
# 3
# 0
# 23
# 23
# Enter an integer: 5
# 5 mod 26 = 5

# %%
#19
character = input("Enter character: ").upper()

number = ord(character) - ord('A')

print(character, "->", number)

number = int(input("Enter any number from (0-25): "))

character = chr(number + ord('A'))

print(number, "->", character)
# Out:
# Enter character:  r
# R -> 17
# Enter any number from (0-25):  7
# 7 -> H

# %%
#20
num = int(input("Enter a number to check: "))

if num < 2:
    print(num, "is not prime")
    
else:
    is_prime = True
    
    for i in range(2, num):
        if num % i == 0:
            is_prime = False
            break
    if is_prime:
        print(num, "is prime")
    else:
        print(num, "is not prime")

start = int(input("Enter starting value: "))

end = int(input("Enter ending value: "))

print("Prime numbers:")

for n in range(start, end + 1):
    if n < 2:
        continue
    prime = True

    for i in range(2, n):
        if n % i == 0:
            prime = False
            break
    if prime:
        print(n, end=" ")
# Out:
# Enter a number to check:  20
# 20 is not prime
# Enter starting value:  1
# Enter ending value:  20
# Prime numbers:
# 2 3 5 7 11 13 17 19

# %%
#21
a = int(input("Enter first integer: "))

b = int(input("Enter second integer: "))

x = a
y = b

while y != 0:
    
    x, y = y, x % y

gcd = x

print("GCD:", gcd)

if gcd == 1:
    print("The numbers are coprime.")
    
else:
    
    print("The numbers are not coprime.")
# Out:
# Enter first integer:  8
# Enter second integer:  15
# GCD: 1
# The numbers are coprime.

# %%
#22
b = int(input("Enter integer: "))

inverse = -1

x = 1

while x < 26:
    if (b * x) % 26 == 1:
        inverse = x
        break
    x = x + 1

if inverse != -1:

    print("Multiplicative inverse of", b, "mod 26 is:", inverse)

else:

    print("Multiplicative inverse does not exist.")
# Out:
# Enter integer:  9
# Multiplicative inverse of 9 mod 26 is: 3
